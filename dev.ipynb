# %%
import pickle
import random
from datetime import date, datetime, timedelta
from dateutil.relativedelta import relativedelta, FR
from typing import Tuple

from itertools import combinations
from collections import OrderedDict, defaultdict

# %%
people = ["Bridget", "Bud", "Carly", "Cody", "Denis", "Eunice", "Jie", "Jonathan", "Kelly", "Kirtiraj", "Kyle B.", "Kyle C.", "Mohar", "Piyush", "Stan"]
teams = {"Team 1": ["Denis", "Mohar", "Jie", "Cody"]}

history = {
    date(2023, 1, 16) : frozenset({frozenset({"Mohar", "Kirtiraj", "Jie"}), 
                      frozenset({"Kelly", "Kyle C.", "Jonathan"}),
                      frozenset({"Eunice", "Denis", "Carly"}),
                      frozenset({"Bridget", "Kyle B.", "Piyush"}),
                      frozenset({"Cody", "Stan", "Bud"})}),
}

today = date.today()
end_period = today

# %%
# date.today()
yesterday = date.today() - timedelta(1)
print(yesterday)
print(date.today() < yesterday)
# Out:
# 2023-01-27
# False

# %%
today
# Out:
# datetime.date(2023, 1, 28)

# %%
date(2022, 12, 25)
# Out:
# datetime.date(2022, 12, 25)

# %%
type(today)
# Out:
# datetime.date

# %%
today = date.today()
# get the next next Friday
end_date = today + relativedelta(weekday=FR(+2))
today_mdy = today.strftime("%m/%d/%Y")
end_mdy = end_date.strftime("%m/%d/%Y")
print(today_mdy, end_mdy)
# Out:
# 01/28/2023 02/10/2023

# %%
for team_name, team in teams.items():
    for pair in combinations(team, 2):
        print(pair)
# Out:
# ('Denis', 'Mohar')
# ('Denis', 'Jie')
# ('Denis', 'Cody')
# ('Mohar', 'Jie')
# ('Mohar', 'Cody')
# ('Jie', 'Cody')

# %%
pairs_so_far = get_pairs_so_far(history, teams)

# %%
def get_pairs_so_far(history: dict, teams: dict) -> defaultdict:
    """
    Description:
        Based on history, get # of occurences of people meeting

    Args:
        history (dict of datetime.date : frozenset(frozenset)): 
            the history of past groups

        teams (dict of str: list[str]): 
            dictionary outlining prexisting teams. We include this to ensure people 
            initially are not matched with people they already see on a regular cadence


    Returns:
        pairs_so_far (defaultdict of frozenset: int):
            Default dictionary where keys are frozenset of a pair and value is 
            # of past interactions, default value of 0
    """
    
    pairs_so_far = defaultdict(int)
    
    # count occurences in history
    for time, val in history.items():
        for elem in list(val):
            for pair in combinations(elem, 2):
                pairs_so_far[frozenset(pair)] += 1
    
    # count occurences in teams
    for team_name, team in teams.items():
        for pair in combinations(team, 2):
            pairs_so_far[frozenset(pair)] += 1
                
        
    return pairs_so_far

def assign_score(candidate, pairs_so_far)->int:
    """
    Description:
        Assign score (the number of past interactions) for a candidate group

    Args:
        candidate (frozenset(frozenset)): a candidate grouping

        pairs_so_far (defaultdict of frozenset: int): 
            Default dictionary where keys are frozenset of a pair and value is 
            # of past interactions, default value of 0

    Returns:
        score (int): # number of past interactions for the entire grouping
        
    """
    score = 0
    for elem in list(candidate):
        for pair in combinations(elem, 2):
            score += pairs_so_far[frozenset(pair)] 
    return score

def choose_group_splits(num_people)->dict:
    """ 
    Description:
        Choose how many groups of 4 and how many groups of 3 to generate

    Args:
        num_people (int): the number of people we're grouping

    Returns:
        split_strategy (dict[str]=int): 
            a dictionary with key group size and value number of groups
    """
    if num_people%4 == 0:
        return {"four": num_people//4, "three": 0}
    elif num_people%3 == 0:
        return {"four": 0, "three": num_people//3}
    else:
        split_strategy = {"four": 0, "three": 0}
        while num_people %3  != 0:
            num_people -= 4
            split_strategy["four"] += 1
        
        while num_people != 0:
            num_people -= 3
            split_strategy["three"] += 1
        
        return split_strategy

def generate_random_groups(people, pairs_so_far, n=1000) -> Tuple[dict, defaultdict]:
    """
    Description:
        Generate n samples of random groupings and keep track of the score. 
        This function also outputs a default dictionary that keeps track of the 
        frequency of the groupings occuring in the random sample

    Args:
        people (list[str]): a list of people for which to generate groups 

        pairs_so_far (defaultdict of frozenset: int): 
            Default dictionary where keys are frozenset of a pair and value is 
            # of past interactions, default value of 0

        n=1000 (int): # of samples to generate, default is 1000

    Returns:

        sample_score_dict (dict of frozenset(frozenset): int): 
            dictionary of key grouping and value score i.e. # of past interactions 
            among people

        repeat_samples_dict (defaultdict of frozenset(frozenset): int): 
            default dictionary of frequency of that grouping among samples generated
    """
    num_people = len(people)
    split_strategy = choose_group_splits(num_people)
    
    sample_score_dict = dict()
    repeat_samples_dict = defaultdict(int)
    for _ in range(n):
        # generate random sample by getting random order
        candidate_order = random.sample(people, num_people)
        
        g4 = candidate_order[0:split_strategy["four"]*4] 
        
        g4_2d = []
        i= 0
        while i < len(g4):
            g4_2d.append(frozenset(g4[i: i+4]))
            i+=4
        if split_strategy["three"] != 0:
            # get remaining part of list
            g3 = candidate_order[split_strategy["four"]*4:] 
            g3_2d = []
            i = 0
            while i < len(g3):
                g3_2d.append(frozenset(g3[i: i+3]))
                i+=3
        
        candidate = frozenset(g4_2d + g3_2d)
        sample_score_dict[candidate] = assign_score(candidate, pairs_so_far)
        repeat_samples_dict[candidate] += 1

    return sample_score_dict, repeat_samples_dict

def choose_best_sampled_group(sample_score_dict):
    """
    Description:
        Given the sampled groups with their scores, 
        choose a group that has the minimum score, i.e. the 
        least number of past interactions

    Args:
        sample_score_dict (dict of frozenset(frozenset): int): 
            dictionary of key grouping and value score i.e. # of past interactions 
            among people
            
    Returns:
        k (frozenset(frozenset)): 
            the best scored grouping that minimizes the number of past interactions
    """
    min_score = min(sample_score_dict.values())
    for k, v in sample_score_dict.items():
        if v == min_score:
            return k

# %%
def write_history(history):
    """ 
    Description:
        Write history as pickled object
    Args:
        history (dict of datetime.date: frozenset(frozenset)): the history of past groups
    Returns: None
    """
    with open('data/history.pickle', 'wb') as handle:
        pickle.dump(history, handle, protocol=pickle.HIGHEST_PROTOCOL)
    handle.close()

def read_history():
    """
    Description:
        Read history from pickled object
    Args:
    Returns: 
        history (dict of datetime.date: frozenset(frozenset)): the history of past groups
    """
    with open('data/history.pickle', 'rb') as handle:
        history = pickle.load(handle)
    handle.close()
    return history

# %%
write_history(history)

# %%
blah = read_history(history)

# %%
blah[sorted(blah.keys())[-1]]
# Out:
# frozenset({frozenset({'Kelly', 'Mohar', 'Stan'}),
#            frozenset({'Denis', 'Kirtiraj', 'Kyle B.'}),
#            frozenset({'Bud', 'Eunice', 'Kyle C.'}),
#            frozenset({'Carly', 'Cody', 'Piyush'}),
#            frozenset({'Bridget', 'Jie', 'Jonathan'})})

# %%
yesterday
# Out:
# datetime.date(2023, 1, 27)

# %%
print(sorted([today, yesterday]))
print(sorted([yesterday, today]))
# Out:
# [datetime.date(2023, 1, 27), datetime.date(2023, 1, 28)]
# [datetime.date(2023, 1, 27), datetime.date(2023, 1, 28)]

# %%
len(history)
# Out:
# 1

# %%
blah
# Out:
# {'01-30-2023': frozenset({frozenset({'Carly', 'Denis', 'Eunice'}),
#             frozenset({'Bud', 'Cody', 'Stan'}),
#             frozenset({'Jonathan', 'Kelly', 'Kyle C.'}),
#             frozenset({'Bridget', 'Kyle B.', 'Piyush'}),
#             frozenset({'Jie', 'Kirtiraj', 'Mohar'})})}

# %%
pairs_so_far = get_pairs_so_far(history)

# %%
pairs_so_far[frozenset({'Kyle C.', 'Kelly'})]
# Out:
# 1

# %%
scores_dict, freq = generate_random_groups(people = people, pairs_so_far = pairs_so_far, n = 1000)

# %%
scores_dict
# Out:
# {frozenset({frozenset({'Cody', 'Denis', 'Stan'}),
#             frozenset({'Eunice', 'Mohar', 'Piyush'}),
#             frozenset({'Bud', 'Kelly', 'Kyle B.'}),
#             frozenset({'Jonathan', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Bridget', 'Carly', 'Jie'})}): 2,
#  frozenset({frozenset({'Carly', 'Jie', 'Kyle C.'}),
#             frozenset({'Eunice', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Bud', 'Cody', 'Mohar'}),
#             frozenset({'Kyle B.', 'Piyush', 'Stan'}),
#             frozenset({'Bridget', 'Denis', 'Jonathan'})}): 2,
#  frozenset({frozenset({'Kelly', 'Kyle B.', 'Stan'}),
#             frozenset({'Bud', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Bridget', 'Carly', 'Jie'}),
#             frozenset({'Cody', 'Denis', 'Eunice'}),
#             frozenset({'Jonathan', 'Kyle C.', 'Mohar'})}): 2,
#  frozenset({frozenset({'Bud', 'Cody', 'Jie'}),
#             frozenset({'Denis', 'Jonathan', 'Mohar'}),
#             frozenset({'Kirtiraj', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Carly', 'Eunice', 'Stan'}),
#             frozenset({'Bridget', 'Kelly', 'Piyush'})}): 3,
#  frozenset({frozenset({'Kirtiraj', 'Kyle B.', 'Mohar'}),
#             frozenset({'Bridget', 'Bud', 'Cody'}),
#             frozenset({'Eunice', 'Jonathan', 'Kyle C.'}),
#             frozenset({'Carly', 'Denis', 'Jie'}),
#             frozenset({'Kelly', 'Piyush', 'Stan'})}): 4,
#  frozenset({frozenset({'Cody', 'Jie', 'Kelly'}),
#             frozenset({'Denis', 'Jonathan', 'Mohar'}),
#             frozenset({'Bridget', 'Bud', 'Piyush'}),
#             frozenset({'Carly', 'Eunice', 'Kyle C.'}),
#             frozenset({'Kirtiraj', 'Kyle B.', 'Stan'})}): 2,
#  frozenset({frozenset({'Bridget', 'Bud', 'Piyush'}),
#             frozenset({'Carly', 'Denis', 'Kelly'}),
#             frozenset({'Eunice', 'Mohar', 'Stan'}),
#             frozenset({'Jie', 'Jonathan', 'Kyle B.'}),
#             frozenset({'Cody', 'Kirtiraj', 'Kyle C.'})}): 2,
#  frozenset({frozenset({'Bridget', 'Denis', 'Kyle C.'}),
#             frozenset({'Cody', 'Eunice', 'Stan'}),
#             frozenset({'Jonathan', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Bud', 'Jie', 'Kelly'}),
#             frozenset({'Carly', 'Mohar', 'Piyush'})}): 1,
#  frozenset({frozenset({'Jie', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Cody', 'Jonathan', 'Mohar'}),
#             frozenset({'Bud', 'Kelly', 'Piyush'}),
#             frozenset({'Bridget', 'Carly', 'Stan'}),
#             frozenset({'Denis', 'Eunice', 'Kyle B.'})}): 2,
#  frozenset({frozenset({'Denis', 'Kyle B.', 'Piyush'}),
#             frozenset({'Carly', 'Kelly', 'Stan'}),
#             frozenset({'Bridget', 'Jie', 'Kirtiraj'}),
#             frozenset({'Jonathan', 'Kyle C.', 'Mohar'}),
#             frozenset({'Bud', 'Cody', 'Eunice'})}): 4,
#  frozenset({frozenset({'Bridget', 'Jie', 'Kelly'}),
#             frozenset({'Bud', 'Eunice', 'Piyush'}),
#             frozenset({'Carly', 'Mohar', 'Stan'}),
#             frozenset({'Denis', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Cody', 'Jonathan', 'Kirtiraj'})}): 0,
#  frozenset({frozenset({'Bridget', 'Eunice', 'Stan'}),
#             frozenset({'Denis', 'Jonathan', 'Kyle B.'}),
#             frozenset({'Bud', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Carly', 'Kelly', 'Mohar'}),
#             frozenset({'Cody', 'Jie', 'Piyush'})}): 0,
#  frozenset({frozenset({'Bridget', 'Bud', 'Jonathan'}),
#             frozenset({'Kelly', 'Kyle B.', 'Piyush'}),
#             frozenset({'Carly', 'Eunice', 'Stan'}),
#             frozenset({'Cody', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Denis', 'Jie', 'Mohar'})}): 3,
#  frozenset({frozenset({'Cody', 'Piyush', 'Stan'}),
#             frozenset({'Jie', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Bud', 'Carly', 'Denis'}),
#             frozenset({'Eunice', 'Kelly', 'Mohar'}),
#             frozenset({'Bridget', 'Jonathan', 'Kirtiraj'})}): 2,
#  frozenset({frozenset({'Bud', 'Kelly', 'Piyush'}),
#             frozenset({'Cody', 'Kyle B.', 'Stan'}),
#             frozenset({'Bridget', 'Kyle C.', 'Mohar'}),
#             frozenset({'Eunice', 'Jie', 'Kirtiraj'}),
#             frozenset({'Carly', 'Denis', 'Jonathan'})}): 3,
#  frozenset({frozenset({'Cody', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Bud', 'Denis', 'Jonathan'}),
#             frozenset({'Bridget', 'Jie', 'Stan'}),
#             frozenset({'Carly', 'Eunice', 'Piyush'}),
#             frozenset({'Kelly', 'Kirtiraj', 'Mohar'})}): 2,
#  frozenset({frozenset({'Kelly', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Bridget', 'Bud', 'Cody'}),
#             frozenset({'Kirtiraj', 'Mohar', 'Piyush'}),
#             frozenset({'Denis', 'Jie', 'Stan'}),
#             frozenset({'Carly', 'Eunice', 'Jonathan'})}): 4,
#  frozenset({frozenset({'Bud', 'Denis', 'Kelly'}),
#             frozenset({'Carly', 'Eunice', 'Stan'}),
#             frozenset({'Jie', 'Kyle C.', 'Mohar'}),
#             frozenset({'Cody', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bridget', 'Jonathan', 'Kirtiraj'})}): 3,
#  frozenset({frozenset({'Carly', 'Kirtiraj', 'Stan'}),
#             frozenset({'Kyle B.', 'Mohar', 'Piyush'}),
#             frozenset({'Bud', 'Jie', 'Kyle C.'}),
#             frozenset({'Cody', 'Eunice', 'Kelly'}),
#             frozenset({'Bridget', 'Denis', 'Jonathan'})}): 1,
#  frozenset({frozenset({'Bridget', 'Mohar', 'Piyush'}),
#             frozenset({'Carly', 'Eunice', 'Kyle B.'}),
#             frozenset({'Bud', 'Jie', 'Kelly'}),
#             frozenset({'Denis', 'Kyle C.', 'Stan'}),
#             frozenset({'Cody', 'Jonathan', 'Kirtiraj'})}): 2,
#  frozenset({frozenset({'Cody', 'Denis', 'Kyle C.'}),
#             frozenset({'Carly', 'Jie', 'Piyush'}),
#             frozenset({'Bud', 'Mohar', 'Stan'}),
#             frozenset({'Eunice', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Kelly', 'Kyle B.'})}): 2,
#  frozenset({frozenset({'Bridget', 'Denis', 'Kirtiraj'}),
#             frozenset({'Kelly', 'Kyle B.', 'Piyush'}),
#             frozenset({'Cody', 'Jie', 'Stan'}),
#             frozenset({'Jonathan', 'Kyle C.', 'Mohar'}),
#             frozenset({'Bud', 'Carly', 'Eunice'})}): 4,
#  frozenset({frozenset({'Eunice', 'Jonathan', 'Stan'}),
#             frozenset({'Carly', 'Jie', 'Kyle B.'}),
#             frozenset({'Kelly', 'Kyle C.', 'Mohar'}),
#             frozenset({'Cody', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Bridget', 'Bud', 'Denis'})}): 1,
#  frozenset({frozenset({'Bridget', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Denis', 'Eunice', 'Kirtiraj'}),
#             frozenset({'Kelly', 'Mohar', 'Stan'}),
#             frozenset({'Bud', 'Carly', 'Piyush'}),
#             frozenset({'Cody', 'Jie', 'Jonathan'})}): 2,
#  frozenset({frozenset({'Carly', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Bridget', 'Eunice', 'Mohar'}),
#             frozenset({'Denis', 'Jonathan', 'Piyush'}),
#             frozenset({'Jie', 'Kelly', 'Stan'}),
#             frozenset({'Bud', 'Cody', 'Kyle B.'})}): 1,
#  frozenset({frozenset({'Cody', 'Eunice', 'Stan'}),
#             frozenset({'Carly', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Bud', 'Jie', 'Jonathan'}),
#             frozenset({'Bridget', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Denis', 'Kelly', 'Mohar'})}): 2,
#  frozenset({frozenset({'Eunice', 'Kelly', 'Piyush'}),
#             frozenset({'Jonathan', 'Kirtiraj', 'Mohar'}),
#             frozenset({'Bridget', 'Kyle C.', 'Stan'}),
#             frozenset({'Bud', 'Carly', 'Jie'}),
#             frozenset({'Cody', 'Denis', 'Kyle B.'})}): 1,
#  frozenset({frozenset({'Cody', 'Kyle B.', 'Stan'}),
#             frozenset({'Bud', 'Denis', 'Piyush'}),
#             frozenset({'Carly', 'Jie', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Eunice', 'Mohar'}),
#             frozenset({'Jonathan', 'Kelly', 'Kyle C.'})}): 5,
#  frozenset({frozenset({'Jonathan', 'Kyle B.', 'Mohar'}),
#             frozenset({'Carly', 'Denis', 'Kelly'}),
#             frozenset({'Kirtiraj', 'Kyle C.', 'Piyush'}),
#             frozenset({'Cody', 'Jie', 'Stan'}),
#             frozenset({'Bridget', 'Bud', 'Eunice'})}): 2,
#  frozenset({frozenset({'Bridget', 'Carly', 'Kelly'}),
#             frozenset({'Jie', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Bud', 'Denis', 'Eunice'}),
#             frozenset({'Cody', 'Piyush', 'Stan'}),
#             frozenset({'Kyle B.', 'Kyle C.', 'Mohar'})}): 3,
#  frozenset({frozenset({'Jie', 'Jonathan', 'Piyush'}),
#             frozenset({'Bridget', 'Denis', 'Mohar'}),
#             frozenset({'Bud', 'Kelly', 'Kyle B.'}),
#             frozenset({'Carly', 'Eunice', 'Kyle C.'}),
#             frozenset({'Cody', 'Kirtiraj', 'Stan'})}): 2,
#  frozenset({frozenset({'Eunice', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Bridget', 'Jonathan', 'Mohar'}),
#             frozenset({'Bud', 'Carly', 'Stan'}),
#             frozenset({'Jie', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Cody', 'Denis', 'Piyush'})}): 2,
#  frozenset({frozenset({'Eunice', 'Kyle B.', 'Stan'}),
#             frozenset({'Bridget', 'Cody', 'Jie'}),
#             frozenset({'Denis', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Bud', 'Jonathan', 'Kyle C.'}),
#             frozenset({'Carly', 'Mohar', 'Piyush'})}): 1,
#  frozenset({frozenset({'Jie', 'Kyle C.', 'Stan'}),
#             frozenset({'Cody', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Denis', 'Mohar'}),
#             frozenset({'Eunice', 'Jonathan', 'Piyush'}),
#             frozenset({'Bud', 'Carly', 'Kyle B.'})}): 0,
#  frozenset({frozenset({'Bud', 'Jonathan', 'Mohar'}),
#             frozenset({'Denis', 'Jie', 'Kyle B.'}),
#             frozenset({'Carly', 'Cody', 'Stan'}),
#             frozenset({'Kelly', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Bridget', 'Eunice', 'Piyush'})}): 3,
#  frozenset({frozenset({'Bridget', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Jie', 'Kelly', 'Stan'}),
#             frozenset({'Bud', 'Denis', 'Mohar'}),
#             frozenset({'Carly', 'Eunice', 'Jonathan'}),
#             frozenset({'Cody', 'Kyle C.', 'Piyush'})}): 2,
#  frozenset({frozenset({'Carly', 'Denis', 'Kelly'}),
#             frozenset({'Bridget', 'Bud', 'Stan'}),
#             frozenset({'Eunice', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Cody', 'Jie', 'Jonathan'}),
#             frozenset({'Kyle B.', 'Kyle C.', 'Mohar'})}): 2,
#  frozenset({frozenset({'Cody', 'Jonathan', 'Mohar'}),
#             frozenset({'Bridget', 'Eunice', 'Kirtiraj'}),
#             frozenset({'Denis', 'Jie', 'Kyle B.'}),
#             frozenset({'Kelly', 'Kyle C.', 'Piyush'}),
#             frozenset({'Bud', 'Carly', 'Stan'})}): 2,
#  frozenset({frozenset({'Bud', 'Cody', 'Piyush'}),
#             frozenset({'Carly', 'Kelly', 'Kyle B.'}),
#             frozenset({'Eunice', 'Mohar', 'Stan'}),
#             frozenset({'Denis', 'Jie', 'Jonathan'}),
#             frozenset({'Bridget', 'Kirtiraj', 'Kyle C.'})}): 1,
#  frozenset({frozenset({'Carly', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Denis', 'Jie', 'Kelly'}),
#             frozenset({'Bridget', 'Cody', 'Piyush'}),
#             frozenset({'Bud', 'Kyle B.', 'Mohar'}),
#             frozenset({'Eunice', 'Jonathan', 'Stan'})}): 1,
#  frozenset({frozenset({'Carly', 'Denis', 'Kelly'}),
#             frozenset({'Kyle B.', 'Mohar', 'Stan'}),
#             frozenset({'Bud', 'Jie', 'Kyle C.'}),
#             frozenset({'Bridget', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Cody', 'Eunice', 'Jonathan'})}): 2,
#  frozenset({frozenset({'Bud', 'Jie', 'Mohar'}),
#             frozenset({'Bridget', 'Cody', 'Denis'}),
#             frozenset({'Eunice', 'Jonathan', 'Kyle C.'}),
#             frozenset({'Carly', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Kyle B.', 'Piyush', 'Stan'})}): 3,
#  frozenset({frozenset({'Bridget', 'Denis', 'Kyle C.'}),
#             frozenset({'Carly', 'Cody', 'Jonathan'}),
#             frozenset({'Kirtiraj', 'Kyle B.', 'Piyush'}),
#             frozenset({'Jie', 'Kelly', 'Stan'}),
#             frozenset({'Bud', 'Eunice', 'Mohar'})}): 1,
#  frozenset({frozenset({'Cody', 'Jie', 'Kelly'}),
#             frozenset({'Bridget', 'Eunice', 'Kirtiraj'}),
#             frozenset({'Jonathan', 'Kyle C.', 'Piyush'}),
#             frozenset({'Denis', 'Mohar', 'Stan'}),
#             frozenset({'Bud', 'Carly', 'Kyle B.'})}): 1,
#  frozenset({frozenset({'Bud', 'Carly', 'Mohar'}),
#             frozenset({'Cody', 'Denis', 'Jie'}),
#             frozenset({'Eunice', 'Kyle B.', 'Piyush'}),
#             frozenset({'Jonathan', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Kyle C.', 'Stan'})}): 2,
#  frozenset({frozenset({'Bud', 'Kyle B.', 'Stan'}),
#             frozenset({'Denis', 'Eunice', 'Kyle C.'}),
#             frozenset({'Kelly', 'Mohar', 'Piyush'}),
#             frozenset({'Carly', 'Cody', 'Jonathan'}),
#             frozenset({'Bridget', 'Jie', 'Kirtiraj'})}): 3,
#  frozenset({frozenset({'Bud', 'Jie', 'Kyle B.'}),
#             frozenset({'Cody', 'Kyle C.', 'Mohar'}),
#             frozenset({'Denis', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Carly', 'Piyush', 'Stan'}),
#             frozenset({'Bridget', 'Eunice', 'Kelly'})}): 0,
#  frozenset({frozenset({'Bud', 'Cody', 'Piyush'}),
#             frozenset({'Bridget', 'Eunice', 'Jie'}),
#             frozenset({'Denis', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Carly', 'Jonathan', 'Mohar'}),
#             frozenset({'Kyle B.', 'Kyle C.', 'Stan'})}): 1,
#  frozenset({frozenset({'Eunice', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Bridget', 'Cody', 'Kyle C.'}),
#             frozenset({'Carly', 'Kelly', 'Mohar'}),
#             frozenset({'Denis', 'Jie', 'Piyush'}),
#             frozenset({'Bud', 'Jonathan', 'Stan'})}): 1,
#  frozenset({frozenset({'Jie', 'Kelly', 'Mohar'}),
#             frozenset({'Bridget', 'Cody', 'Stan'}),
#             frozenset({'Denis', 'Eunice', 'Piyush'}),
#             frozenset({'Bud', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Carly', 'Jonathan', 'Kirtiraj'})}): 3,
#  frozenset({frozenset({'Kelly', 'Kyle B.', 'Piyush'}),
#             frozenset({'Eunice', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Cody', 'Jie', 'Jonathan'}),
#             frozenset({'Carly', 'Mohar', 'Stan'}),
#             frozenset({'Bridget', 'Bud', 'Denis'})}): 1,
#  frozenset({frozenset({'Cody', 'Kyle B.', 'Stan'}),
#             frozenset({'Bridget', 'Kelly', 'Mohar'}),
#             frozenset({'Eunice', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Denis', 'Jie', 'Kyle C.'}),
#             frozenset({'Bud', 'Carly', 'Piyush'})}): 1,
#  frozenset({frozenset({'Bridget', 'Cody', 'Kyle C.'}),
#             frozenset({'Jonathan', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Mohar', 'Piyush', 'Stan'}),
#             frozenset({'Denis', 'Eunice', 'Kyle B.'}),
#             frozenset({'Bud', 'Carly', 'Jie'})}): 2,
#  frozenset({frozenset({'Denis', 'Kyle B.', 'Stan'}),
#             frozenset({'Cody', 'Eunice', 'Kirtiraj'}),
#             frozenset({'Jonathan', 'Kyle C.', 'Piyush'}),
#             frozenset({'Bridget', 'Kelly', 'Mohar'}),
#             frozenset({'Bud', 'Carly', 'Jie'})}): 1,
#  frozenset({frozenset({'Eunice', 'Jie', 'Jonathan'}),
#             frozenset({'Bud', 'Kelly', 'Kyle B.'}),
#             frozenset({'Bridget', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Cody', 'Mohar', 'Stan'}),
#             frozenset({'Carly', 'Denis', 'Piyush'})}): 2,
#  frozenset({frozenset({'Carly', 'Jie', 'Stan'}),
#             frozenset({'Eunice', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Cody', 'Kelly', 'Kyle B.'}),
#             frozenset({'Jonathan', 'Kyle C.', 'Mohar'}),
#             frozenset({'Bridget', 'Bud', 'Denis'})}): 1,
#  frozenset({frozenset({'Bridget', 'Eunice', 'Jie'}),
#             frozenset({'Bud', 'Carly', 'Mohar'}),
#             frozenset({'Cody', 'Denis', 'Kirtiraj'}),
#             frozenset({'Jonathan', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Kelly', 'Piyush', 'Stan'})}): 1,
#  frozenset({frozenset({'Eunice', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Carly', 'Denis', 'Stan'}),
#             frozenset({'Jie', 'Mohar', 'Piyush'}),
#             frozenset({'Bridget', 'Bud', 'Kelly'}),
#             frozenset({'Cody', 'Jonathan', 'Kirtiraj'})}): 2,
#  frozenset({frozenset({'Eunice', 'Kelly', 'Stan'}),
#             frozenset({'Denis', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Bud', 'Jie', 'Piyush'}),
#             frozenset({'Cody', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Carly', 'Mohar'})}): 0,
#  frozenset({frozenset({'Bridget', 'Denis', 'Kyle C.'}),
#             frozenset({'Cody', 'Kelly', 'Mohar'}),
#             frozenset({'Jie', 'Kyle B.', 'Piyush'}),
#             frozenset({'Carly', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Bud', 'Eunice', 'Stan'})}): 2,
#  frozenset({frozenset({'Bridget', 'Denis', 'Kyle C.'}),
#             frozenset({'Cody', 'Kelly', 'Mohar'}),
#             frozenset({'Eunice', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Bud', 'Carly', 'Jie'}),
#             frozenset({'Jonathan', 'Kyle B.', 'Stan'})}): 0,
#  frozenset({frozenset({'Carly', 'Eunice', 'Mohar'}),
#             frozenset({'Denis', 'Jonathan', 'Piyush'}),
#             frozenset({'Kirtiraj', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Bridget', 'Cody', 'Kelly'}),
#             frozenset({'Bud', 'Jie', 'Stan'})}): 2,
#  frozenset({frozenset({'Bud', 'Kyle C.', 'Mohar'}),
#             frozenset({'Jie', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Cody', 'Eunice'}),
#             frozenset({'Kyle B.', 'Piyush', 'Stan'}),
#             frozenset({'Carly', 'Denis', 'Jonathan'})}): 3,
#  frozenset({frozenset({'Cody', 'Mohar', 'Stan'}),
#             frozenset({'Eunice', 'Kelly', 'Piyush'}),
#             frozenset({'Jie', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Bud', 'Carly', 'Denis'}),
#             frozenset({'Bridget', 'Jonathan', 'Kyle C.'})}): 4,
#  frozenset({frozenset({'Eunice', 'Kelly', 'Piyush'}),
#             frozenset({'Bridget', 'Kyle C.', 'Stan'}),
#             frozenset({'Cody', 'Jie', 'Kirtiraj'}),
#             frozenset({'Bud', 'Carly', 'Jonathan'}),
#             frozenset({'Denis', 'Kyle B.', 'Mohar'})}): 1,
#  frozenset({frozenset({'Bridget', 'Eunice', 'Kirtiraj'}),
#             frozenset({'Kelly', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bud', 'Denis', 'Mohar'}),
#             frozenset({'Carly', 'Cody', 'Jie'}),
#             frozenset({'Jonathan', 'Kyle C.', 'Stan'})}): 2,
#  frozenset({frozenset({'Bud', 'Kelly', 'Piyush'}),
#             frozenset({'Cody', 'Jonathan', 'Stan'}),
#             frozenset({'Carly', 'Denis', 'Jie'}),
#             frozenset({'Bridget', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Eunice', 'Kyle B.', 'Mohar'})}): 2,
#  frozenset({frozenset({'Jie', 'Kelly', 'Mohar'}),
#             frozenset({'Cody', 'Denis', 'Stan'}),
#             frozenset({'Jonathan', 'Kyle C.', 'Piyush'}),
#             frozenset({'Carly', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Bridget', 'Bud', 'Eunice'})}): 3,
#  frozenset({frozenset({'Denis', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Kyle B.', 'Kyle C.', 'Mohar'}),
#             frozenset({'Bud', 'Carly', 'Cody'}),
#             frozenset({'Eunice', 'Jie', 'Stan'}),
#             frozenset({'Bridget', 'Kelly', 'Piyush'})}): 2,
#  frozenset({frozenset({'Cody', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Bud', 'Eunice', 'Jie'}),
#             frozenset({'Bridget', 'Denis', 'Mohar'}),
#             frozenset({'Carly', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Kelly', 'Piyush', 'Stan'})}): 0,
#  frozenset({frozenset({'Cody', 'Jie', 'Kyle B.'}),
#             frozenset({'Carly', 'Kyle C.', 'Mohar'}),
#             frozenset({'Bridget', 'Denis', 'Kelly'}),
#             frozenset({'Eunice', 'Jonathan', 'Piyush'}),
#             frozenset({'Bud', 'Kirtiraj', 'Stan'})}): 1,
#  frozenset({frozenset({'Denis', 'Kyle B.', 'Piyush'}),
#             frozenset({'Jonathan', 'Kelly', 'Kyle C.'}),
#             frozenset({'Carly', 'Kirtiraj', 'Mohar'}),
#             frozenset({'Bridget', 'Jie', 'Stan'}),
#             frozenset({'Bud', 'Cody', 'Eunice'})}): 6,
#  frozenset({frozenset({'Kyle B.', 'Mohar', 'Piyush'}),
#             frozenset({'Bridget', 'Kelly', 'Stan'}),
#             frozenset({'Eunice', 'Jie', 'Jonathan'}),
#             frozenset({'Cody', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Bud', 'Carly', 'Denis'})}): 2,
#  frozenset({frozenset({'Cody', 'Kelly', 'Piyush'}),
#             frozenset({'Bridget', 'Carly', 'Denis'}),
#             frozenset({'Bud', 'Eunice', 'Kirtiraj'}),
#             frozenset({'Kyle B.', 'Kyle C.', 'Stan'}),
#             frozenset({'Jie', 'Jonathan', 'Mohar'})}): 2,
#  frozenset({frozenset({'Carly', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Eunice', 'Mohar', 'Stan'}),
#             frozenset({'Jie', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bud', 'Cody', 'Kelly'}),
#             frozenset({'Bridget', 'Denis', 'Jonathan'})}): 2,
#  frozenset({frozenset({'Bridget', 'Eunice', 'Jonathan'}),
#             frozenset({'Carly', 'Cody', 'Kelly'}),
#             frozenset({'Bud', 'Kyle B.', 'Piyush'}),
#             frozenset({'Jie', 'Mohar', 'Stan'}),
#             frozenset({'Denis', 'Kirtiraj', 'Kyle C.'})}): 2,
#  frozenset({frozenset({'Bud', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Piyush', 'Stan'}),
#             frozenset({'Carly', 'Jie', 'Kyle B.'}),
#             frozenset({'Denis', 'Eunice', 'Mohar'}),
#             frozenset({'Cody', 'Jonathan', 'Kyle C.'})}): 3,
#  frozenset({frozenset({'Denis', 'Kelly', 'Kyle C.'}),
#             frozenset({'Cody', 'Jonathan', 'Stan'}),
#             frozenset({'Bud', 'Carly', 'Kirtiraj'}),
#             frozenset({'Jie', 'Kyle B.', 'Mohar'}),
#             frozenset({'Bridget', 'Eunice', 'Piyush'})}): 4,
#  frozenset({frozenset({'Carly', 'Kelly', 'Kyle B.'}),
#             frozenset({'Jie', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Kyle C.', 'Mohar'}),
#             frozenset({'Cody', 'Denis', 'Piyush'}),
#             frozenset({'Bud', 'Eunice', 'Stan'})}): 2,
#  frozenset({frozenset({'Eunice', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bridget', 'Bud', 'Cody'}),
#             frozenset({'Carly', 'Denis', 'Kirtiraj'}),
#             frozenset({'Kelly', 'Kyle C.', 'Mohar'}),
#             frozenset({'Jie', 'Jonathan', 'Stan'})}): 4,
#  frozenset({frozenset({'Bridget', 'Kelly', 'Mohar'}),
#             frozenset({'Bud', 'Denis', 'Eunice'}),
#             frozenset({'Cody', 'Piyush', 'Stan'}),
#             frozenset({'Kirtiraj', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Carly', 'Jie', 'Jonathan'})}): 2,
#  frozenset({frozenset({'Kirtiraj', 'Kyle B.', 'Mohar'}),
#             frozenset({'Jonathan', 'Piyush', 'Stan'}),
#             frozenset({'Carly', 'Eunice', 'Kyle C.'}),
#             frozenset({'Bridget', 'Denis', 'Kelly'}),
#             frozenset({'Bud', 'Cody', 'Jie'})}): 3,
#  frozenset({frozenset({'Cody', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Bridget', 'Denis', 'Jie'}),
#             frozenset({'Jonathan', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Bud', 'Carly', 'Stan'}),
#             frozenset({'Eunice', 'Kelly', 'Mohar'})}): 1,
#  frozenset({frozenset({'Bridget', 'Carly', 'Kelly'}),
#             frozenset({'Cody', 'Kyle B.', 'Stan'}),
#             frozenset({'Bud', 'Denis', 'Jonathan'}),
#             frozenset({'Jie', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Eunice', 'Kyle C.', 'Mohar'})}): 2,
#  frozenset({frozenset({'Bridget', 'Denis', 'Kirtiraj'}),
#             frozenset({'Bud', 'Kyle C.', 'Mohar'}),
#             frozenset({'Eunice', 'Jie', 'Piyush'}),
#             frozenset({'Carly', 'Kyle B.', 'Stan'}),
#             frozenset({'Cody', 'Jonathan', 'Kelly'})}): 1,
#  frozenset({frozenset({'Bridget', 'Denis', 'Mohar'}),
#             frozenset({'Jonathan', 'Kelly', 'Kyle C.'}),
#             frozenset({'Jie', 'Kyle B.', 'Stan'}),
#             frozenset({'Bud', 'Cody', 'Eunice'}),
#             frozenset({'Carly', 'Kirtiraj', 'Piyush'})}): 4,
#  frozenset({frozenset({'Bud', 'Denis', 'Stan'}),
#             frozenset({'Eunice', 'Kelly', 'Kyle C.'}),
#             frozenset({'Cody', 'Jonathan', 'Piyush'}),
#             frozenset({'Jie', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Bridget', 'Carly', 'Mohar'})}): 3,
#  frozenset({frozenset({'Bridget', 'Eunice', 'Mohar'}),
#             frozenset({'Bud', 'Denis', 'Kyle B.'}),
#             frozenset({'Cody', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Carly', 'Jonathan', 'Kelly'}),
#             frozenset({'Jie', 'Piyush', 'Stan'})}): 1,
#  frozenset({frozenset({'Bridget', 'Carly', 'Denis'}),
#             frozenset({'Bud', 'Jie', 'Kyle B.'}),
#             frozenset({'Kelly', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Cody', 'Jonathan', 'Stan'}),
#             frozenset({'Eunice', 'Kyle C.', 'Mohar'})}): 2,
#  frozenset({frozenset({'Cody', 'Jie', 'Kyle C.'}),
#             frozenset({'Bridget', 'Denis', 'Kelly'}),
#             frozenset({'Bud', 'Kyle B.', 'Mohar'}),
#             frozenset({'Carly', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Eunice', 'Jonathan', 'Stan'})}): 0,
#  frozenset({frozenset({'Jie', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Cody', 'Piyush', 'Stan'}),
#             frozenset({'Bridget', 'Eunice', 'Kyle B.'}),
#             frozenset({'Bud', 'Carly', 'Kyle C.'}),
#             frozenset({'Denis', 'Kelly', 'Mohar'})}): 3,
#  frozenset({frozenset({'Bridget', 'Bud', 'Jie'}),
#             frozenset({'Denis', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Kirtiraj', 'Mohar', 'Stan'}),
#             frozenset({'Eunice', 'Jonathan', 'Kelly'}),
#             frozenset({'Carly', 'Cody', 'Piyush'})}): 2,
#  frozenset({frozenset({'Carly', 'Cody', 'Mohar'}),
#             frozenset({'Eunice', 'Kelly', 'Stan'}),
#             frozenset({'Bud', 'Jie', 'Kyle B.'}),
#             frozenset({'Kirtiraj', 'Kyle C.', 'Piyush'}),
#             frozenset({'Bridget', 'Denis', 'Jonathan'})}): 0,
#  frozenset({frozenset({'Bridget', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Bud', 'Jonathan', 'Mohar'}),
#             frozenset({'Kyle C.', 'Piyush', 'Stan'}),
#             frozenset({'Cody', 'Eunice', 'Jie'}),
#             frozenset({'Carly', 'Denis', 'Kelly'})}): 2,
#  frozenset({frozenset({'Cody', 'Kyle B.', 'Stan'}),
#             frozenset({'Bridget', 'Bud', 'Piyush'}),
#             frozenset({'Denis', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Carly', 'Eunice', 'Jie'}),
#             frozenset({'Kelly', 'Kyle C.', 'Mohar'})}): 4,
#  frozenset({frozenset({'Bridget', 'Jonathan', 'Mohar'}),
#             frozenset({'Denis', 'Eunice', 'Piyush'}),
#             frozenset({'Bud', 'Jie', 'Kelly'}),
#             frozenset({'Cody', 'Kyle C.', 'Stan'}),
#             frozenset({'Carly', 'Kirtiraj', 'Kyle B.'})}): 2,
#  frozenset({frozenset({'Bud', 'Denis', 'Piyush'}),
#             frozenset({'Carly', 'Cody', 'Jonathan'}),
#             frozenset({'Bridget', 'Jie', 'Kirtiraj'}),
#             frozenset({'Eunice', 'Kyle C.', 'Stan'}),
#             frozenset({'Kelly', 'Kyle B.', 'Mohar'})}): 1,
#  frozenset({frozenset({'Kirtiraj', 'Kyle C.', 'Stan'}),
#             frozenset({'Denis', 'Jonathan', 'Kyle B.'}),
#             frozenset({'Bud', 'Eunice', 'Jie'}),
#             frozenset({'Bridget', 'Cody', 'Mohar'}),
#             frozenset({'Carly', 'Kelly', 'Piyush'})}): 0,
#  frozenset({frozenset({'Jie', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Bud', 'Denis', 'Jonathan'}),
#             frozenset({'Kelly', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bridget', 'Cody', 'Eunice'}),
#             frozenset({'Carly', 'Mohar', 'Stan'})}): 2,
#  frozenset({frozenset({'Denis', 'Jonathan', 'Piyush'}),
#             frozenset({'Carly', 'Cody', 'Kyle C.'}),
#             frozenset({'Bridget', 'Eunice', 'Kelly'}),
#             frozenset({'Bud', 'Kirtiraj', 'Stan'}),
#             frozenset({'Jie', 'Kyle B.', 'Mohar'})}): 2,
#  frozenset({frozenset({'Bridget', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Denis', 'Kelly', 'Stan'}),
#             frozenset({'Bud', 'Cody', 'Jonathan'}),
#             frozenset({'Jie', 'Kyle C.', 'Piyush'}),
#             frozenset({'Carly', 'Eunice', 'Mohar'})}): 3,
#  frozenset({frozenset({'Bridget', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Denis', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Cody', 'Jie', 'Stan'}),
#             frozenset({'Bud', 'Carly', 'Jonathan'}),
#             frozenset({'Eunice', 'Kelly', 'Mohar'})}): 2,
#  frozenset({frozenset({'Jie', 'Kelly', 'Mohar'}),
#             frozenset({'Denis', 'Jonathan', 'Kyle C.'}),
#             frozenset({'Eunice', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Bridget', 'Carly', 'Stan'}),
#             frozenset({'Bud', 'Cody', 'Kyle B.'})}): 3,
#  frozenset({frozenset({'Denis', 'Jie', 'Jonathan'}),
#             frozenset({'Bridget', 'Cody', 'Kelly'}),
#             frozenset({'Bud', 'Carly', 'Kyle C.'}),
#             frozenset({'Kirtiraj', 'Piyush', 'Stan'}),
#             frozenset({'Eunice', 'Kyle B.', 'Mohar'})}): 0,
#  frozenset({frozenset({'Jie', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Denis', 'Kyle B.', 'Piyush'}),
#             frozenset({'Carly', 'Kelly', 'Kyle C.'}),
#             frozenset({'Bridget', 'Cody', 'Mohar'}),
#             frozenset({'Bud', 'Eunice', 'Stan'})}): 4,
#  frozenset({frozenset({'Bridget', 'Cody', 'Kirtiraj'}),
#             frozenset({'Bud', 'Denis', 'Piyush'}),
#             frozenset({'Eunice', 'Mohar', 'Stan'}),
#             frozenset({'Jonathan', 'Kelly', 'Kyle C.'}),
#             frozenset({'Carly', 'Jie', 'Kyle B.'})}): 3,
#  frozenset({frozenset({'Kelly', 'Mohar', 'Piyush'}),
#             frozenset({'Bridget', 'Denis', 'Stan'}),
#             frozenset({'Eunice', 'Jie', 'Kyle B.'}),
#             frozenset({'Bud', 'Cody', 'Kirtiraj'}),
#             frozenset({'Carly', 'Jonathan', 'Kyle C.'})}): 2,
#  frozenset({frozenset({'Bud', 'Jonathan', 'Kyle B.'}),
#             frozenset({'Eunice', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Carly', 'Denis', 'Mohar'}),
#             frozenset({'Bridget', 'Cody', 'Kyle C.'}),
#             frozenset({'Jie', 'Piyush', 'Stan'})}): 1,
#  frozenset({frozenset({'Carly', 'Cody', 'Mohar'}),
#             frozenset({'Bud', 'Eunice', 'Piyush'}),
#             frozenset({'Bridget', 'Kelly', 'Stan'}),
#             frozenset({'Jonathan', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Denis', 'Jie', 'Kyle C.'})}): 0,
#  frozenset({frozenset({'Jonathan', 'Piyush', 'Stan'}),
#             frozenset({'Bud', 'Denis', 'Eunice'}),
#             frozenset({'Carly', 'Cody', 'Kyle C.'}),
#             frozenset({'Bridget', 'Kelly', 'Kyle B.'}),
#             frozenset({'Jie', 'Kirtiraj', 'Mohar'})}): 5,
#  frozenset({frozenset({'Bridget', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Kelly', 'Mohar', 'Piyush'}),
#             frozenset({'Denis', 'Kirtiraj', 'Stan'}),
#             frozenset({'Cody', 'Jie', 'Jonathan'}),
#             frozenset({'Bud', 'Carly', 'Eunice'})}): 2,
#  frozenset({frozenset({'Denis', 'Kelly', 'Kyle C.'}),
#             frozenset({'Eunice', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Bridget', 'Bud', 'Carly'}),
#             frozenset({'Cody', 'Jonathan', 'Stan'}),
#             frozenset({'Jie', 'Mohar', 'Piyush'})}): 3,
#  frozenset({frozenset({'Bud', 'Kyle B.', 'Stan'}),
#             frozenset({'Bridget', 'Carly', 'Kelly'}),
#             frozenset({'Cody', 'Kyle C.', 'Mohar'}),
#             frozenset({'Denis', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Eunice', 'Jie', 'Piyush'})}): 1,
#  frozenset({frozenset({'Jonathan', 'Kelly', 'Mohar'}),
#             frozenset({'Carly', 'Kirtiraj', 'Stan'}),
#             frozenset({'Eunice', 'Jie', 'Kyle C.'}),
#             frozenset({'Bridget', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bud', 'Cody', 'Denis'})}): 5,
#  frozenset({frozenset({'Eunice', 'Jonathan', 'Mohar'}),
#             frozenset({'Bridget', 'Bud', 'Piyush'}),
#             frozenset({'Carly', 'Denis', 'Kyle B.'}),
#             frozenset({'Cody', 'Jie', 'Kirtiraj'}),
#             frozenset({'Kelly', 'Kyle C.', 'Stan'})}): 4,
#  frozenset({frozenset({'Kelly', 'Kyle B.', 'Stan'}),
#             frozenset({'Jonathan', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Bridget', 'Cody', 'Kyle C.'}),
#             frozenset({'Bud', 'Denis', 'Mohar'}),
#             frozenset({'Carly', 'Eunice', 'Jie'})}): 1,
#  frozenset({frozenset({'Carly', 'Kirtiraj', 'Stan'}),
#             frozenset({'Bridget', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bud', 'Eunice', 'Kelly'}),
#             frozenset({'Cody', 'Denis', 'Jonathan'}),
#             frozenset({'Jie', 'Kyle C.', 'Mohar'})}): 4,
#  frozenset({frozenset({'Jie', 'Kyle C.', 'Piyush'}),
#             frozenset({'Eunice', 'Kelly', 'Kyle B.'}),
#             frozenset({'Bridget', 'Cody', 'Mohar'}),
#             frozenset({'Denis', 'Jonathan', 'Stan'}),
#             frozenset({'Bud', 'Carly', 'Kirtiraj'})}): 0,
#  frozenset({frozenset({'Bud', 'Denis', 'Stan'}),
#             frozenset({'Carly', 'Cody', 'Eunice'}),
#             frozenset({'Jonathan', 'Kelly', 'Kyle B.'}),
#             frozenset({'Jie', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Bridget', 'Kyle C.', 'Mohar'})}): 4,
#  frozenset({frozenset({'Eunice', 'Kyle B.', 'Stan'}),
#             frozenset({'Bridget', 'Mohar', 'Piyush'}),
#             frozenset({'Cody', 'Kelly', 'Kyle C.'}),
#             frozenset({'Bud', 'Jie', 'Kirtiraj'}),
#             frozenset({'Carly', 'Denis', 'Jonathan'})}): 4,
#  frozenset({frozenset({'Bridget', 'Carly', 'Eunice'}),
#             frozenset({'Cody', 'Mohar', 'Piyush'}),
#             frozenset({'Kelly', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Bud', 'Denis', 'Kyle C.'}),
#             frozenset({'Jie', 'Jonathan', 'Stan'})}): 1,
#  frozenset({frozenset({'Bridget', 'Jonathan', 'Mohar'}),
#             frozenset({'Cody', 'Denis', 'Jie'}),
#             frozenset({'Carly', 'Kelly', 'Kyle B.'}),
#             frozenset({'Kirtiraj', 'Kyle C.', 'Piyush'}),
#             frozenset({'Bud', 'Eunice', 'Stan'})}): 1,
#  frozenset({frozenset({'Carly', 'Denis', 'Piyush'}),
#             frozenset({'Bridget', 'Bud', 'Stan'}),
#             frozenset({'Jonathan', 'Kelly', 'Kyle C.'}),
#             frozenset({'Cody', 'Eunice', 'Kyle B.'}),
#             frozenset({'Jie', 'Kirtiraj', 'Mohar'})}): 8,
#  frozenset({frozenset({'Bridget', 'Carly', 'Kelly'}),
#             frozenset({'Eunice', 'Mohar', 'Stan'}),
#             frozenset({'Bud', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Jie', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Cody', 'Denis', 'Piyush'})}): 0,
#  frozenset({frozenset({'Carly', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Bud', 'Denis', 'Stan'}),
#             frozenset({'Kyle B.', 'Mohar', 'Piyush'}),
#             frozenset({'Cody', 'Eunice', 'Kelly'}),
#             frozenset({'Bridget', 'Jie', 'Jonathan'})}): 2,
#  frozenset({frozenset({'Kelly', 'Mohar', 'Piyush'}),
#             frozenset({'Cody', 'Denis', 'Jie'}),
#             frozenset({'Bud', 'Eunice', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Carly', 'Jonathan'}),
#             frozenset({'Kyle B.', 'Kyle C.', 'Stan'})}): 0,
#  frozenset({frozenset({'Denis', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Bud', 'Jonathan', 'Piyush'}),
#             frozenset({'Carly', 'Kirtiraj', 'Mohar'}),
#             frozenset({'Eunice', 'Jie', 'Stan'}),
#             frozenset({'Bridget', 'Cody', 'Kelly'})}): 1,
#  frozenset({frozenset({'Bud', 'Jonathan', 'Kelly'}),
#             frozenset({'Jie', 'Kyle C.', 'Piyush'}),
#             frozenset({'Carly', 'Kyle B.', 'Mohar'}),
#             frozenset({'Cody', 'Denis', 'Eunice'}),
#             frozenset({'Bridget', 'Kirtiraj', 'Stan'})}): 2,
#  frozenset({frozenset({'Jonathan', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Denis', 'Eunice', 'Jie'}),
#             frozenset({'Kyle C.', 'Mohar', 'Stan'}),
#             frozenset({'Bridget', 'Cody', 'Kelly'}),
#             frozenset({'Bud', 'Carly', 'Kyle B.'})}): 1,
#  frozenset({frozenset({'Eunice', 'Jie', 'Mohar'}),
#             frozenset({'Carly', 'Jonathan', 'Stan'}),
#             frozenset({'Bud', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Denis', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bridget', 'Cody', 'Kelly'})}): 2,
#  frozenset({frozenset({'Denis', 'Jonathan', 'Kyle C.'}),
#             frozenset({'Cody', 'Jie', 'Stan'}),
#             frozenset({'Bud', 'Kyle B.', 'Mohar'}),
#             frozenset({'Carly', 'Eunice', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Kelly', 'Piyush'})}): 4,
#  frozenset({frozenset({'Denis', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Mohar', 'Piyush', 'Stan'}),
#             frozenset({'Carly', 'Cody', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Eunice', 'Kelly'}),
#             frozenset({'Bud', 'Jie', 'Jonathan'})}): 0,
#  frozenset({frozenset({'Carly', 'Jonathan', 'Stan'}),
#             frozenset({'Jie', 'Kelly', 'Kyle C.'}),
#             frozenset({'Eunice', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Cody', 'Denis', 'Mohar'}),
#             frozenset({'Bridget', 'Bud', 'Kyle B.'})}): 2,
#  frozenset({frozenset({'Bridget', 'Bud', 'Jonathan'}),
#             frozenset({'Cody', 'Eunice', 'Piyush'}),
#             frozenset({'Denis', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Jie', 'Mohar', 'Stan'}),
#             frozenset({'Carly', 'Kyle B.', 'Kyle C.'})}): 1,
#  frozenset({frozenset({'Bridget', 'Eunice', 'Kyle C.'}),
#             frozenset({'Jie', 'Jonathan', 'Kelly'}),
#             frozenset({'Kirtiraj', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bud', 'Carly', 'Stan'}),
#             frozenset({'Cody', 'Denis', 'Mohar'})}): 3,
#  frozenset({frozenset({'Eunice', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Carly', 'Kelly', 'Stan'}),
#             frozenset({'Cody', 'Jonathan', 'Piyush'}),
#             frozenset({'Bridget', 'Bud', 'Kyle C.'}),
#             frozenset({'Denis', 'Jie', 'Mohar'})}): 1,
#  frozenset({frozenset({'Bridget', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Jonathan', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Eunice', 'Jie', 'Stan'}),
#             frozenset({'Carly', 'Mohar', 'Piyush'}),
#             frozenset({'Bud', 'Cody', 'Denis'})}): 2,
#  frozenset({frozenset({'Carly', 'Cody', 'Kyle B.'}),
#             frozenset({'Denis', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Jie', 'Piyush'}),
#             frozenset({'Kelly', 'Kyle C.', 'Mohar'}),
#             frozenset({'Bud', 'Eunice', 'Stan'})}): 3,
#  frozenset({frozenset({'Eunice', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Carly', 'Cody', 'Jonathan'}),
#             frozenset({'Mohar', 'Piyush', 'Stan'}),
#             frozenset({'Bud', 'Jie', 'Kyle C.'}),
#             frozenset({'Bridget', 'Denis', 'Kelly'})}): 0,
#  frozenset({frozenset({'Denis', 'Eunice', 'Kirtiraj'}),
#             frozenset({'Bud', 'Jie', 'Kyle B.'}),
#             frozenset({'Carly', 'Cody', 'Jonathan'}),
#             frozenset({'Kelly', 'Kyle C.', 'Piyush'}),
#             frozenset({'Bridget', 'Mohar', 'Stan'})}): 2,
#  frozenset({frozenset({'Denis', 'Jonathan', 'Piyush'}),
#             frozenset({'Carly', 'Jie', 'Kyle B.'}),
#             frozenset({'Cody', 'Kyle C.', 'Stan'}),
#             frozenset({'Bridget', 'Bud', 'Eunice'}),
#             frozenset({'Kelly', 'Kirtiraj', 'Mohar'})}): 2,
#  frozenset({frozenset({'Bridget', 'Mohar', 'Piyush'}),
#             frozenset({'Cody', 'Denis', 'Stan'}),
#             frozenset({'Eunice', 'Jie', 'Jonathan'}),
#             frozenset({'Bud', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Carly', 'Kelly', 'Kyle C.'})}): 3,
#  frozenset({frozenset({'Denis', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Cody', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Bud', 'Jie', 'Piyush'}),
#             frozenset({'Carly', 'Eunice', 'Jonathan'}),
#             frozenset({'Bridget', 'Mohar', 'Stan'})}): 1,
#  frozenset({frozenset({'Bridget', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Cody', 'Eunice', 'Jie'}),
#             frozenset({'Jonathan', 'Piyush', 'Stan'}),
#             frozenset({'Bud', 'Carly', 'Kyle C.'}),
#             frozenset({'Denis', 'Kelly', 'Mohar'})}): 1,
#  frozenset({frozenset({'Kelly', 'Mohar', 'Stan'}),
#             frozenset({'Denis', 'Jie', 'Kyle C.'}),
#             frozenset({'Cody', 'Jonathan', 'Kyle B.'}),
#             frozenset({'Bud', 'Carly', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Eunice', 'Piyush'})}): 1,
#  frozenset({frozenset({'Cody', 'Jonathan', 'Mohar'}),
#             frozenset({'Carly', 'Eunice', 'Kelly'}),
#             frozenset({'Denis', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Bud', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Bridget', 'Jie', 'Stan'})}): 1,
#  frozenset({frozenset({'Carly', 'Cody', 'Eunice'}),
#             frozenset({'Bridget', 'Kelly', 'Kyle C.'}),
#             frozenset({'Jie', 'Jonathan', 'Kyle B.'}),
#             frozenset({'Bud', 'Denis', 'Mohar'}),
#             frozenset({'Kirtiraj', 'Piyush', 'Stan'})}): 2,
#  frozenset({frozenset({'Kirtiraj', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bridget', 'Carly', 'Jonathan'}),
#             frozenset({'Bud', 'Denis', 'Kelly'}),
#             frozenset({'Eunice', 'Jie', 'Kyle C.'}),
#             frozenset({'Cody', 'Mohar', 'Stan'})}): 2,
#  frozenset({frozenset({'Carly', 'Denis', 'Kyle B.'}),
#             frozenset({'Bridget', 'Cody', 'Piyush'}),
#             frozenset({'Bud', 'Jonathan', 'Stan'}),
#             frozenset({'Eunice', 'Jie', 'Kirtiraj'}),
#             frozenset({'Kelly', 'Kyle C.', 'Mohar'})}): 5,
#  frozenset({frozenset({'Jonathan', 'Kelly', 'Mohar'}),
#             frozenset({'Kirtiraj', 'Kyle C.', 'Stan'}),
#             frozenset({'Bud', 'Carly', 'Jie'}),
#             frozenset({'Cody', 'Denis', 'Kyle B.'}),
#             frozenset({'Bridget', 'Eunice', 'Piyush'})}): 2,
#  frozenset({frozenset({'Eunice', 'Kyle C.', 'Stan'}),
#             frozenset({'Bridget', 'Jie', 'Jonathan'}),
#             frozenset({'Bud', 'Cody', 'Denis'}),
#             frozenset({'Carly', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Kelly', 'Kyle B.', 'Mohar'})}): 1,
#  frozenset({frozenset({'Cody', 'Jie', 'Kelly'}),
#             frozenset({'Kyle B.', 'Kyle C.', 'Piyush'}),
#             frozenset({'Carly', 'Eunice', 'Stan'}),
#             frozenset({'Jonathan', 'Kirtiraj', 'Mohar'}),
#             frozenset({'Bridget', 'Bud', 'Denis'})}): 3,
#  frozenset({frozenset({'Jie', 'Jonathan', 'Piyush'}),
#             frozenset({'Bridget', 'Cody', 'Stan'}),
#             frozenset({'Bud', 'Denis', 'Eunice'}),
#             frozenset({'Carly', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Kelly', 'Kyle C.', 'Mohar'})}): 3,
#  frozenset({frozenset({'Bud', 'Kirtiraj', 'Mohar'}),
#             frozenset({'Cody', 'Kelly', 'Stan'}),
#             frozenset({'Denis', 'Eunice', 'Jie'}),
#             frozenset({'Bridget', 'Kyle B.', 'Piyush'}),
#             frozenset({'Carly', 'Jonathan', 'Kyle C.'})}): 7,
#  frozenset({frozenset({'Bridget', 'Jonathan', 'Mohar'}),
#             frozenset({'Bud', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Denis', 'Kelly', 'Kyle B.'}),
#             frozenset({'Carly', 'Eunice', 'Jie'}),
#             frozenset({'Cody', 'Kyle C.', 'Stan'})}): 2,
#  frozenset({frozenset({'Bud', 'Carly', 'Cody'}),
#             frozenset({'Jie', 'Kelly', 'Kyle C.'}),
#             frozenset({'Bridget', 'Denis', 'Piyush'}),
#             frozenset({'Jonathan', 'Kyle B.', 'Stan'}),
#             frozenset({'Eunice', 'Kirtiraj', 'Mohar'})}): 4,
#  frozenset({frozenset({'Bridget', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Cody', 'Eunice', 'Mohar'}),
#             frozenset({'Bud', 'Denis', 'Kelly'}),
#             frozenset({'Carly', 'Kyle C.', 'Piyush'}),
#             frozenset({'Jie', 'Jonathan', 'Stan'})}): 1,
#  frozenset({frozenset({'Bridget', 'Jie', 'Mohar'}),
#             frozenset({'Bud', 'Jonathan', 'Kyle C.'}),
#             frozenset({'Cody', 'Denis', 'Kelly'}),
#             frozenset({'Eunice', 'Kirtiraj', 'Stan'}),
#             frozenset({'Carly', 'Kyle B.', 'Piyush'})}): 3,
#  frozenset({frozenset({'Bridget', 'Cody', 'Jie'}),
#             frozenset({'Jonathan', 'Kelly', 'Kyle B.'}),
#             frozenset({'Denis', 'Kyle C.', 'Piyush'}),
#             frozenset({'Bud', 'Carly', 'Stan'}),
#             frozenset({'Eunice', 'Kirtiraj', 'Mohar'})}): 3,
#  frozenset({frozenset({'Bridget', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Cody', 'Kyle C.', 'Mohar'}),
#             frozenset({'Bud', 'Denis', 'Jonathan'}),
#             frozenset({'Carly', 'Eunice', 'Stan'}),
#             frozenset({'Jie', 'Kyle B.', 'Piyush'})}): 2,
#  frozenset({frozenset({'Jonathan', 'Kirtiraj', 'Stan'}),
#             frozenset({'Bridget', 'Cody', 'Kyle C.'}),
#             frozenset({'Denis', 'Jie', 'Piyush'}),
#             frozenset({'Bud', 'Carly', 'Kyle B.'}),
#             frozenset({'Eunice', 'Kelly', 'Mohar'})}): 0,
#  frozenset({frozenset({'Denis', 'Kirtiraj', 'Mohar'}),
#             frozenset({'Carly', 'Jie', 'Kyle C.'}),
#             frozenset({'Bud', 'Cody', 'Stan'}),
#             frozenset({'Bridget', 'Eunice', 'Kyle B.'}),
#             frozenset({'Jonathan', 'Kelly', 'Piyush'})}): 6,
#  frozenset({frozenset({'Carly', 'Kirtiraj', 'Stan'}),
#             frozenset({'Bridget', 'Cody', 'Jie'}),
#             frozenset({'Denis', 'Jonathan', 'Kyle B.'}),
#             frozenset({'Eunice', 'Kyle C.', 'Piyush'}),
#             frozenset({'Bud', 'Kelly', 'Mohar'})}): 0,
#  frozenset({frozenset({'Denis', 'Eunice', 'Jie'}),
#             frozenset({'Bridget', 'Kyle B.', 'Mohar'}),
#             frozenset({'Carly', 'Kelly', 'Stan'}),
#             frozenset({'Bud', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Cody', 'Kyle C.', 'Piyush'})}): 2,
#  frozenset({frozenset({'Bridget', 'Eunice', 'Kyle C.'}),
#             frozenset({'Denis', 'Jonathan', 'Piyush'}),
#             frozenset({'Bud', 'Cody', 'Mohar'}),
#             frozenset({'Carly', 'Jie', 'Kyle B.'}),
#             frozenset({'Kelly', 'Kirtiraj', 'Stan'})}): 1,
#  frozenset({frozenset({'Jie', 'Kyle C.', 'Stan'}),
#             frozenset({'Carly', 'Eunice', 'Mohar'}),
#             frozenset({'Bud', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Cody', 'Denis', 'Kelly'}),
#             frozenset({'Bridget', 'Jonathan', 'Kyle B.'})}): 2,
#  frozenset({frozenset({'Cody', 'Jonathan', 'Mohar'}),
#             frozenset({'Denis', 'Jie', 'Kyle B.'}),
#             frozenset({'Bridget', 'Kelly', 'Kyle C.'}),
#             frozenset({'Bud', 'Eunice', 'Kirtiraj'}),
#             frozenset({'Carly', 'Piyush', 'Stan'})}): 1,
#  frozenset({frozenset({'Jonathan', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Carly', 'Kelly', 'Kyle B.'}),
#             frozenset({'Bud', 'Kyle C.', 'Mohar'}),
#             frozenset({'Bridget', 'Cody', 'Eunice'}),
#             frozenset({'Denis', 'Jie', 'Stan'})}): 0,
#  frozenset({frozenset({'Bud', 'Kelly', 'Piyush'}),
#             frozenset({'Denis', 'Kyle B.', 'Stan'}),
#             frozenset({'Bridget', 'Cody', 'Kirtiraj'}),
#             frozenset({'Carly', 'Jie', 'Mohar'}),
#             frozenset({'Eunice', 'Jonathan', 'Kyle C.'})}): 2,
#  frozenset({frozenset({'Bridget', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Jonathan', 'Piyush', 'Stan'}),
#             frozenset({'Jie', 'Kelly', 'Kyle C.'}),
#             frozenset({'Cody', 'Denis', 'Mohar'}),
#             frozenset({'Bud', 'Carly', 'Eunice'})}): 3,
#  frozenset({frozenset({'Jonathan', 'Piyush', 'Stan'}),
#             frozenset({'Denis', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Cody', 'Eunice', 'Mohar'}),
#             frozenset({'Bridget', 'Bud', 'Carly'}),
#             frozenset({'Jie', 'Kelly', 'Kyle C.'})}): 1,
#  frozenset({frozenset({'Denis', 'Jie', 'Kyle B.'}),
#             frozenset({'Bridget', 'Eunice', 'Mohar'}),
#             frozenset({'Bud', 'Jonathan', 'Piyush'}),
#             frozenset({'Carly', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Cody', 'Kyle C.', 'Stan'})}): 1,
#  frozenset({frozenset({'Cody', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Bud', 'Eunice', 'Kyle C.'}),
#             frozenset({'Carly', 'Jie', 'Mohar'}),
#             frozenset({'Bridget', 'Denis', 'Piyush'}),
#             frozenset({'Jonathan', 'Kelly', 'Stan'})}): 3,
#  frozenset({frozenset({'Bridget', 'Mohar', 'Piyush'}),
#             frozenset({'Cody', 'Denis', 'Kirtiraj'}),
#             frozenset({'Carly', 'Kelly', 'Kyle B.'}),
#             frozenset({'Eunice', 'Jonathan', 'Kyle C.'}),
#             frozenset({'Bud', 'Jie', 'Stan'})}): 3,
#  frozenset({frozenset({'Denis', 'Kelly', 'Kyle C.'}),
#             frozenset({'Cody', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Bridget', 'Jonathan', 'Stan'}),
#             frozenset({'Carly', 'Eunice', 'Jie'}),
#             frozenset({'Bud', 'Mohar', 'Piyush'})}): 2,
#  frozenset({frozenset({'Bridget', 'Bud', 'Jonathan'}),
#             frozenset({'Carly', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Cody', 'Eunice', 'Jie'}),
#             frozenset({'Mohar', 'Piyush', 'Stan'}),
# ...
#             frozenset({'Cody', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Bud', 'Carly', 'Kelly'})}): 1,
#  frozenset({frozenset({'Kirtiraj', 'Kyle B.', 'Mohar'}),
#             frozenset({'Bridget', 'Kelly', 'Kyle C.'}),
#             frozenset({'Carly', 'Jonathan', 'Stan'}),
#             frozenset({'Bud', 'Jie', 'Piyush'}),
#             frozenset({'Cody', 'Denis', 'Eunice'})}): 3,
#  frozenset({frozenset({'Cody', 'Jie', 'Kelly'}),
#             frozenset({'Bridget', 'Bud', 'Piyush'}),
#             frozenset({'Denis', 'Eunice', 'Kirtiraj'}),
#             frozenset({'Carly', 'Kyle C.', 'Mohar'}),
#             frozenset({'Jonathan', 'Kyle B.', 'Stan'})}): 2,
#  frozenset({frozenset({'Cody', 'Denis', 'Kyle C.'}),
#             frozenset({'Bud', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Carly', 'Eunice', 'Stan'}),
#             frozenset({'Jie', 'Jonathan', 'Mohar'}),
#             frozenset({'Bridget', 'Kelly', 'Piyush'})}): 3,
#  frozenset({frozenset({'Bud', 'Jie', 'Mohar'}),
#             frozenset({'Bridget', 'Eunice', 'Kyle B.'}),
#             frozenset({'Carly', 'Denis', 'Stan'}),
#             frozenset({'Kelly', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Cody', 'Jonathan', 'Piyush'})}): 4,
#  frozenset({frozenset({'Bridget', 'Jie', 'Kelly'}),
#             frozenset({'Bud', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Cody', 'Kyle B.', 'Mohar'}),
#             frozenset({'Carly', 'Denis', 'Kyle C.'}),
#             frozenset({'Eunice', 'Jonathan', 'Stan'})}): 1,
#  frozenset({frozenset({'Kelly', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Bridget', 'Kirtiraj', 'Mohar'}),
#             frozenset({'Bud', 'Cody', 'Stan'}),
#             frozenset({'Eunice', 'Jonathan', 'Piyush'}),
#             frozenset({'Carly', 'Denis', 'Jie'})}): 6,
#  frozenset({frozenset({'Denis', 'Jonathan', 'Kelly'}),
#             frozenset({'Bridget', 'Kirtiraj', 'Mohar'}),
#             frozenset({'Cody', 'Jie', 'Kyle C.'}),
#             frozenset({'Kyle B.', 'Piyush', 'Stan'}),
#             frozenset({'Bud', 'Carly', 'Eunice'})}): 4,
#  frozenset({frozenset({'Carly', 'Jonathan', 'Piyush'}),
#             frozenset({'Bud', 'Denis', 'Jie'}),
#             frozenset({'Bridget', 'Eunice', 'Stan'}),
#             frozenset({'Cody', 'Kelly', 'Mohar'}),
#             frozenset({'Kirtiraj', 'Kyle B.', 'Kyle C.'})}): 0,
#  frozenset({frozenset({'Carly', 'Kirtiraj', 'Stan'}),
#             frozenset({'Bridget', 'Cody', 'Kyle C.'}),
#             frozenset({'Eunice', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bud', 'Denis', 'Kelly'}),
#             frozenset({'Jie', 'Jonathan', 'Mohar'})}): 2,
#  frozenset({frozenset({'Jie', 'Jonathan', 'Piyush'}),
#             frozenset({'Bridget', 'Kelly', 'Kyle C.'}),
#             frozenset({'Carly', 'Eunice', 'Kyle B.'}),
#             frozenset({'Denis', 'Mohar', 'Stan'}),
#             frozenset({'Bud', 'Cody', 'Kirtiraj'})}): 3,
#  frozenset({frozenset({'Denis', 'Eunice', 'Kirtiraj'}),
#             frozenset({'Bud', 'Kyle C.', 'Mohar'}),
#             frozenset({'Bridget', 'Cody', 'Stan'}),
#             frozenset({'Jie', 'Kyle B.', 'Piyush'}),
#             frozenset({'Carly', 'Jonathan', 'Kelly'})}): 4,
#  frozenset({frozenset({'Carly', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Eunice', 'Mohar', 'Piyush'}),
#             frozenset({'Cody', 'Denis', 'Jie'}),
#             frozenset({'Bud', 'Kelly', 'Kyle B.'}),
#             frozenset({'Bridget', 'Jonathan', 'Stan'})}): 0,
#  frozenset({frozenset({'Jie', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Jonathan', 'Kyle B.', 'Mohar'}),
#             frozenset({'Carly', 'Cody', 'Kelly'}),
#             frozenset({'Denis', 'Piyush', 'Stan'}),
#             frozenset({'Bridget', 'Bud', 'Eunice'})}): 1,
#  frozenset({frozenset({'Kelly', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Carly', 'Piyush', 'Stan'}),
#             frozenset({'Bridget', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Bud', 'Cody', 'Jie'}),
#             frozenset({'Denis', 'Eunice', 'Mohar'})}): 3,
#  frozenset({frozenset({'Cody', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Jonathan', 'Kirtiraj', 'Stan'}),
#             frozenset({'Bud', 'Denis', 'Jie'}),
#             frozenset({'Bridget', 'Eunice', 'Kelly'}),
#             frozenset({'Carly', 'Mohar', 'Piyush'})}): 0,
#  frozenset({frozenset({'Cody', 'Jonathan', 'Mohar'}),
#             frozenset({'Denis', 'Jie', 'Kyle B.'}),
#             frozenset({'Carly', 'Kelly', 'Kyle C.'}),
#             frozenset({'Bridget', 'Bud', 'Eunice'}),
#             frozenset({'Kirtiraj', 'Piyush', 'Stan'})}): 1,
#  frozenset({frozenset({'Kelly', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Carly', 'Piyush', 'Stan'}),
#             frozenset({'Bridget', 'Jie', 'Jonathan'}),
#             frozenset({'Bud', 'Cody', 'Kyle C.'}),
#             frozenset({'Denis', 'Eunice', 'Mohar'})}): 2,
#  frozenset({frozenset({'Denis', 'Kirtiraj', 'Mohar'}),
#             frozenset({'Bridget', 'Carly', 'Eunice'}),
#             frozenset({'Cody', 'Kelly', 'Kyle C.'}),
#             frozenset({'Bud', 'Jie', 'Piyush'}),
#             frozenset({'Jonathan', 'Kyle B.', 'Stan'})}): 3,
#  frozenset({frozenset({'Carly', 'Kirtiraj', 'Stan'}),
#             frozenset({'Cody', 'Mohar', 'Piyush'}),
#             frozenset({'Eunice', 'Kelly', 'Kyle C.'}),
#             frozenset({'Denis', 'Jie', 'Jonathan'}),
#             frozenset({'Bridget', 'Bud', 'Kyle B.'})}): 2,
#  frozenset({frozenset({'Eunice', 'Kyle B.', 'Stan'}),
#             frozenset({'Carly', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Bridget', 'Jie', 'Mohar'}),
#             frozenset({'Bud', 'Denis', 'Kelly'}),
#             frozenset({'Cody', 'Jonathan', 'Piyush'})}): 1,
#  frozenset({frozenset({'Denis', 'Kelly', 'Kyle C.'}),
#             frozenset({'Jie', 'Kyle B.', 'Piyush'}),
#             frozenset({'Carly', 'Jonathan', 'Mohar'}),
#             frozenset({'Cody', 'Kirtiraj', 'Stan'}),
#             frozenset({'Bridget', 'Bud', 'Eunice'})}): 3,
#  frozenset({frozenset({'Cody', 'Kelly', 'Piyush'}),
#             frozenset({'Carly', 'Eunice', 'Kyle B.'}),
#             frozenset({'Bud', 'Denis', 'Jonathan'}),
#             frozenset({'Kirtiraj', 'Mohar', 'Stan'}),
#             frozenset({'Bridget', 'Jie', 'Kyle C.'})}): 2,
#  frozenset({frozenset({'Cody', 'Kelly', 'Piyush'}),
#             frozenset({'Jie', 'Jonathan', 'Kyle C.'}),
#             frozenset({'Carly', 'Eunice', 'Mohar'}),
#             frozenset({'Denis', 'Kirtiraj', 'Stan'}),
#             frozenset({'Bridget', 'Bud', 'Kyle B.'})}): 3,
#  frozenset({frozenset({'Carly', 'Kirtiraj', 'Stan'}),
#             frozenset({'Kelly', 'Mohar', 'Piyush'}),
#             frozenset({'Bud', 'Jie', 'Kyle B.'}),
#             frozenset({'Bridget', 'Cody', 'Denis'}),
#             frozenset({'Eunice', 'Jonathan', 'Kyle C.'})}): 1,
#  frozenset({frozenset({'Kyle C.', 'Piyush', 'Stan'}),
#             frozenset({'Eunice', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Cody', 'Denis', 'Jie'}),
#             frozenset({'Bridget', 'Carly', 'Jonathan'}),
#             frozenset({'Bud', 'Kelly', 'Mohar'})}): 0,
#  frozenset({frozenset({'Jie', 'Kyle C.', 'Stan'}),
#             frozenset({'Cody', 'Mohar', 'Piyush'}),
#             frozenset({'Bud', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Bridget', 'Eunice', 'Kelly'}),
#             frozenset({'Carly', 'Denis', 'Jonathan'})}): 1,
#  frozenset({frozenset({'Jonathan', 'Kelly', 'Kyle B.'}),
#             frozenset({'Carly', 'Kyle C.', 'Mohar'}),
#             frozenset({'Bud', 'Cody', 'Eunice'}),
#             frozenset({'Bridget', 'Jie', 'Kirtiraj'}),
#             frozenset({'Denis', 'Piyush', 'Stan'})}): 3,
#  frozenset({frozenset({'Cody', 'Jie', 'Kyle B.'}),
#             frozenset({'Denis', 'Mohar', 'Piyush'}),
#             frozenset({'Bud', 'Eunice', 'Kyle C.'}),
#             frozenset({'Bridget', 'Kirtiraj', 'Stan'}),
#             frozenset({'Carly', 'Jonathan', 'Kelly'})}): 1,
#  frozenset({frozenset({'Jonathan', 'Kyle B.', 'Mohar'}),
#             frozenset({'Eunice', 'Jie', 'Kelly'}),
#             frozenset({'Bridget', 'Cody', 'Kirtiraj'}),
#             frozenset({'Bud', 'Piyush', 'Stan'}),
#             frozenset({'Carly', 'Denis', 'Kyle C.'})}): 2,
#  frozenset({frozenset({'Bridget', 'Jonathan', 'Kelly'}),
#             frozenset({'Bud', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Cody', 'Piyush', 'Stan'}),
#             frozenset({'Carly', 'Eunice', 'Mohar'}),
#             frozenset({'Denis', 'Jie', 'Kyle C.'})}): 3,
#  frozenset({frozenset({'Denis', 'Kyle B.', 'Stan'}),
#             frozenset({'Jie', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Bud', 'Eunice', 'Kyle C.'}),
#             frozenset({'Bridget', 'Cody', 'Piyush'}),
#             frozenset({'Carly', 'Kelly', 'Mohar'})}): 2,
#  frozenset({frozenset({'Bridget', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Cody', 'Kyle B.', 'Mohar'}),
#             frozenset({'Denis', 'Jie', 'Kyle C.'}),
#             frozenset({'Bud', 'Carly', 'Piyush'}),
#             frozenset({'Eunice', 'Jonathan', 'Stan'})}): 0,
#  frozenset({frozenset({'Eunice', 'Jie', 'Kelly'}),
#             frozenset({'Bridget', 'Cody', 'Kirtiraj'}),
#             frozenset({'Jonathan', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Mohar', 'Piyush', 'Stan'}),
#             frozenset({'Bud', 'Carly', 'Denis'})}): 2,
#  frozenset({frozenset({'Carly', 'Jonathan', 'Piyush'}),
#             frozenset({'Denis', 'Eunice', 'Stan'}),
#             frozenset({'Bridget', 'Bud', 'Cody'}),
#             frozenset({'Jie', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Kyle B.', 'Kyle C.', 'Mohar'})}): 3,
#  frozenset({frozenset({'Carly', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Bridget', 'Cody', 'Kyle B.'}),
#             frozenset({'Bud', 'Jie', 'Piyush'}),
#             frozenset({'Denis', 'Eunice', 'Mohar'}),
#             frozenset({'Jonathan', 'Kelly', 'Stan'})}): 3,
#  frozenset({frozenset({'Cody', 'Kelly', 'Stan'}),
#             frozenset({'Bud', 'Jie', 'Kyle B.'}),
#             frozenset({'Carly', 'Eunice', 'Jonathan'}),
#             frozenset({'Kirtiraj', 'Kyle C.', 'Mohar'}),
#             frozenset({'Bridget', 'Denis', 'Piyush'})}): 4,
#  frozenset({frozenset({'Bridget', 'Mohar', 'Piyush'}),
#             frozenset({'Carly', 'Denis', 'Kyle B.'}),
#             frozenset({'Bud', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Eunice', 'Jie', 'Stan'}),
#             frozenset({'Cody', 'Jonathan', 'Kelly'})}): 3,
#  frozenset({frozenset({'Denis', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Carly', 'Piyush'}),
#             frozenset({'Cody', 'Kelly', 'Kyle B.'}),
#             frozenset({'Jie', 'Kyle C.', 'Mohar'}),
#             frozenset({'Bud', 'Eunice', 'Stan'})}): 3,
#  frozenset({frozenset({'Eunice', 'Jie', 'Kelly'}),
#             frozenset({'Bridget', 'Carly', 'Kyle B.'}),
#             frozenset({'Bud', 'Mohar', 'Stan'}),
#             frozenset({'Denis', 'Kyle C.', 'Piyush'}),
#             frozenset({'Cody', 'Jonathan', 'Kirtiraj'})}): 2,
#  frozenset({frozenset({'Cody', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Denis', 'Jonathan', 'Kyle C.'}),
#             frozenset({'Jie', 'Kelly', 'Stan'}),
#             frozenset({'Bridget', 'Bud', 'Mohar'}),
#             frozenset({'Carly', 'Eunice', 'Piyush'})}): 2,
#  frozenset({frozenset({'Cody', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Eunice', 'Jonathan', 'Kyle B.'}),
#             frozenset({'Bud', 'Denis', 'Kyle C.'}),
#             frozenset({'Bridget', 'Jie', 'Stan'}),
#             frozenset({'Carly', 'Mohar', 'Piyush'})}): 0,
#  frozenset({frozenset({'Carly', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Cody', 'Jonathan', 'Mohar'}),
#             frozenset({'Denis', 'Jie', 'Kelly'}),
#             frozenset({'Bridget', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bud', 'Eunice', 'Stan'})}): 4,
#  frozenset({frozenset({'Bud', 'Eunice', 'Jonathan'}),
#             frozenset({'Kelly', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Bridget', 'Denis', 'Mohar'}),
#             frozenset({'Carly', 'Cody', 'Kyle C.'}),
#             frozenset({'Jie', 'Piyush', 'Stan'})}): 0,
#  frozenset({frozenset({'Denis', 'Eunice', 'Stan'}),
#             frozenset({'Bud', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bridget', 'Jie', 'Mohar'}),
#             frozenset({'Carly', 'Kelly', 'Kyle C.'}),
#             frozenset({'Cody', 'Jonathan', 'Kirtiraj'})}): 4,
#  frozenset({frozenset({'Bridget', 'Jonathan', 'Kelly'}),
#             frozenset({'Denis', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Carly', 'Cody', 'Stan'}),
#             frozenset({'Bud', 'Jie', 'Piyush'}),
#             frozenset({'Eunice', 'Kirtiraj', 'Mohar'})}): 3,
#  frozenset({frozenset({'Jie', 'Kelly', 'Mohar'}),
#             frozenset({'Carly', 'Cody', 'Jonathan'}),
#             frozenset({'Eunice', 'Kyle B.', 'Piyush'}),
#             frozenset({'Denis', 'Kirtiraj', 'Stan'}),
#             frozenset({'Bridget', 'Bud', 'Kyle C.'})}): 2,
#  frozenset({frozenset({'Bridget', 'Eunice', 'Kirtiraj'}),
#             frozenset({'Carly', 'Cody', 'Piyush'}),
#             frozenset({'Bud', 'Jonathan', 'Stan'}),
#             frozenset({'Denis', 'Jie', 'Kyle C.'}),
#             frozenset({'Kelly', 'Kyle B.', 'Mohar'})}): 1,
#  frozenset({frozenset({'Jie', 'Jonathan', 'Kelly'}),
#             frozenset({'Bridget', 'Cody', 'Kyle B.'}),
#             frozenset({'Bud', 'Carly', 'Piyush'}),
#             frozenset({'Eunice', 'Kirtiraj', 'Stan'}),
#             frozenset({'Denis', 'Kyle C.', 'Mohar'})}): 2,
#  frozenset({frozenset({'Bud', 'Carly', 'Mohar'}),
#             frozenset({'Cody', 'Piyush', 'Stan'}),
#             frozenset({'Jie', 'Jonathan', 'Kyle B.'}),
#             frozenset({'Denis', 'Kirtiraj', 'Kyle C.'}),
#             frozenset({'Bridget', 'Eunice', 'Kelly'})}): 1,
#  frozenset({frozenset({'Kyle C.', 'Mohar', 'Piyush'}),
#             frozenset({'Denis', 'Kirtiraj', 'Stan'}),
#             frozenset({'Carly', 'Jie', 'Kelly'}),
#             frozenset({'Cody', 'Jonathan', 'Kyle B.'}),
#             frozenset({'Bridget', 'Bud', 'Eunice'})}): 0,
#  frozenset({frozenset({'Jonathan', 'Kirtiraj', 'Piyush'}),
#             frozenset({'Jie', 'Mohar', 'Stan'}),
#             frozenset({'Bridget', 'Carly', 'Kyle C.'}),
#             frozenset({'Denis', 'Eunice', 'Kyle B.'}),
#             frozenset({'Bud', 'Cody', 'Kelly'})}): 3,
#  frozenset({frozenset({'Jie', 'Jonathan', 'Kirtiraj'}),
#             frozenset({'Bud', 'Kelly', 'Kyle C.'}),
#             frozenset({'Cody', 'Denis', 'Kyle B.'}),
#             frozenset({'Carly', 'Mohar', 'Stan'}),
#             frozenset({'Bridget', 'Eunice', 'Piyush'})}): 3,
#  frozenset({frozenset({'Cody', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Denis', 'Mohar'}),
#             frozenset({'Jie', 'Kyle B.', 'Piyush'}),
#             frozenset({'Bud', 'Carly', 'Kyle C.'}),
#             frozenset({'Eunice', 'Jonathan', 'Stan'})}): 1,
#  frozenset({frozenset({'Bud', 'Jie', 'Mohar'}),
#             frozenset({'Eunice', 'Kyle B.', 'Kyle C.'}),
#             frozenset({'Carly', 'Cody', 'Jonathan'}),
#             frozenset({'Bridget', 'Denis', 'Kelly'}),
#             frozenset({'Kirtiraj', 'Piyush', 'Stan'})}): 1,
#  frozenset({frozenset({'Cody', 'Mohar', 'Piyush'}),
#             frozenset({'Denis', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Jie', 'Jonathan', 'Kyle B.'}),
#             frozenset({'Bridget', 'Carly', 'Kyle C.'}),
#             frozenset({'Bud', 'Eunice', 'Stan'})}): 1,
#  frozenset({frozenset({'Bud', 'Jie', 'Mohar'}),
#             frozenset({'Carly', 'Cody', 'Kyle B.'}),
#             frozenset({'Denis', 'Eunice', 'Piyush'}),
#             frozenset({'Jonathan', 'Kelly', 'Kirtiraj'}),
#             frozenset({'Bridget', 'Kyle C.', 'Stan'})}): 3,
#  frozenset({frozenset({'Bud', 'Jie', 'Mohar'}),
#             frozenset({'Denis', 'Kelly', 'Stan'}),
#             frozenset({'Cody', 'Eunice', 'Piyush'}),
#             frozenset({'Carly', 'Kirtiraj', 'Kyle B.'}),
#             frozenset({'Bridget', 'Jonathan', 'Kyle C.'})}): 2,
#  frozenset({frozenset({'Bridget', 'Bud', 'Jie'}),
#             frozenset({'Cody', 'Kelly', 'Kyle B.'}),
#             frozenset({'Carly', 'Jonathan', 'Kyle C.'}),
#             frozenset({'Kirtiraj', 'Piyush', 'Stan'}),
#             frozenset({'Denis', 'Eunice', 'Mohar'})}): 2}

# %%
final_group = choose_best_sampled_group(sample_score_dict = scores_dict)

# %%
final_group
# Out:
# frozenset({frozenset({'Bridget', 'Jie', 'Kelly'}),
#            frozenset({'Bud', 'Eunice', 'Piyush'}),
#            frozenset({'Carly', 'Mohar', 'Stan'}),
#            frozenset({'Denis', 'Kyle B.', 'Kyle C.'}),
#            frozenset({'Cody', 'Jonathan', 'Kirtiraj'})})

# %%
newlist = [today, today + relativedelta(weekday=FR(+2))]
print(newlist)
# Out:
# [datetime.date(2023, 1, 28), datetime.date(2023, 2, 10)]

# %%
" to ".join([str(x) for x in newlist])
# Out:
# '2023-01-28 to 2023-02-10'
